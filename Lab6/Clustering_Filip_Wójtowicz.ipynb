# %% [markdown]
# # Clustering
# ## K-means clustering - example I

# %% [markdown]
# **Example 1:**

# %%
from sklearn.datasets import make_blobs 
 
help(make_blobs)  # there I analyse the function parameters
# Out:
# Help on function make_blobs in module sklearn.datasets._samples_generator:
#
# make_blobs(n_samples=100, n_features=2, *, centers=None, cluster_std=1.0, center_box=(-10.0, 10.0), shuffle=True, random_state=None, return_centers=False)
#     Generate isotropic Gaussian blobs for clustering.
#
#     Read more in the :ref:`User Guide <sample_generators>`.
#
#     Parameters
#     ----------
#     n_samples : int or array-like, optional (default=100)
#         If int, it is the total number of points equally divided among
#         clusters.
#         If array-like, each element of the sequence indicates
#         the number of samples per cluster.
#
#         .. versionchanged:: v0.20
#             one can now pass an array-like to the ``n_samples`` parameter
#
#     n_features : int, optional (default=2)
#         The number of features for each sample.
#
#     centers : int or array of shape [n_centers, n_features], optional
#         (default=None)
# ...

# %% [markdown]
# **Example 2:**

# %%
X, y = make_blobs(n_samples=120, centers=4, n_features=2, cluster_std=0.4)  # generating the dataset

# %% [markdown]
# **Example 3:**

# %%
X  # show features
# Out:
# array([[ -9.92120952,  -3.58061262],
#        [  5.5752417 ,   4.60449553],
#        [  5.94921187,  -1.54834386],
#        [ -9.35739866,  -3.05747423],
#        [  5.68073393,   3.86268187],
#        [  7.00983613,  -0.9073527 ],
#        [ -9.3602146 ,  -7.72170031],
#        [ -9.21406622,  -7.33298186],
#        [ -9.29573537,  -8.71443066],
#        [  5.99203099,  -0.99810457],
#        [  5.76091794,   4.76882393],
#        [  6.60864124,  -0.72174976],
#        [  6.92858629,  -1.69416996],
#        [ -8.78574095,  -8.45299635],
#        [ -8.32063895,  -8.72929274],
#        [-10.12571364,  -3.05754883],
#        [ -8.76993183,  -7.82604783],
#        [ -9.48665142,  -8.44227791],
#        [  6.5540765 ,  -0.9953542 ],
#        [ -9.30303247,  -8.27888282],
#        [ -9.44210451,  -7.6786497 ],
#        [ -9.67635646,  -7.71914339],
#        [-10.36315793,  -2.27313292],
#        [  5.56096376,   4.4520232 ],
#        [ -9.36843504,  -2.93812544],
# ...

# %%
X.shape  # quick check of 'X' shape
# Out:
# (120, 2)

# %%
y
# Out:
# array([1, 3, 2, 1, 3, 2, 0, 0, 0, 2, 3, 2, 2, 0, 0, 1, 0, 0, 2, 0, 0, 0,
#        1, 3, 1, 3, 2, 2, 1, 1, 3, 2, 1, 1, 0, 0, 0, 3, 0, 2, 1, 1, 0, 0,
#        0, 1, 2, 3, 0, 3, 1, 3, 2, 1, 3, 2, 2, 2, 1, 3, 2, 2, 3, 1, 3, 2,
#        2, 3, 3, 2, 0, 3, 1, 3, 1, 0, 1, 2, 0, 3, 1, 1, 3, 3, 1, 1, 2, 0,
#        0, 3, 0, 1, 1, 1, 3, 3, 0, 2, 2, 3, 0, 2, 1, 3, 3, 2, 1, 2, 3, 2,
#        3, 0, 3, 1, 0, 0, 0, 2, 1, 2])

# %%
y.shape  # quick check of 'y' shape
# Out:
# (120,)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# %% [markdown]
# **Example 4:**

# %%
plt.scatter(X[:, 0], X[:, 1])  # plot for both features
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 5:**

# %%
# Creating an object
kmeans = KMeans(n_clusters=4)

# Learning model
kmeans.fit(X)
#kmeans.fit(X, y)  # ???

# Predicting values
Y_pred = kmeans.predict(X)
#Y_pred = kmeans.labels_  # another option!

# %% [markdown]
# **Example 6:**

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y_pred)  # plot for the predicted outcome
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 7:**

# %%
kmeans.inertia_  # function responsible for calculating inertia
# Out:
# 31.301178694274736

# %% [markdown]
# ## K-means clustering - example II

# %% [markdown]
# **Example 1:**

# %%
X, y = make_blobs(n_samples=120, centers=5, n_features=2, cluster_std=0.8)  # new data generated

# %%
X
# Out:
# array([[ -2.84953673,  -2.79935933],
#        [ -1.96476261,  -6.68640141],
#        [ -1.44707712,  -1.40703103],
#        [ -9.85309829,  -6.61545596],
#        [ -1.68250446,  -7.20219859],
#        [ -0.64211518,  -6.09337377],
#        [ -5.21547887,  -7.91334184],
#        [ -1.53381578,  -1.31026282],
#        [-10.48001   ,  -5.75542622],
#        [ -5.31124211,  -8.73429496],
#        [  3.92346461,   2.32971456],
#        [-10.64416465,  -5.76894415],
#        [ -2.05087276,  -0.66819166],
#        [ -1.6878227 ,  -1.32493603],
#        [ -5.90819749,  -7.81774648],
#        [ -4.50177821,  -7.10393367],
#        [-10.15697887,  -6.38477003],
#        [  3.71220339,  -0.14566906],
#        [ -2.81031061,  -1.14974565],
#        [ -1.5088654 ,  -1.90211435],
#        [-11.64551148,  -6.30318993],
#        [ -4.77304797,  -6.73263091],
#        [ -3.50403712,  -1.85877529],
#        [ -3.14160689,  -1.12593669],
#        [ -0.92510689,  -3.2761284 ],
# ...

# %%
X.shape
# Out:
# (120, 2)

# %%
y
# Out:
# array([4, 3, 4, 1, 3, 3, 2, 4, 1, 2, 0, 1, 4, 4, 2, 2, 1, 0, 4, 4, 1, 2,
#        4, 4, 4, 0, 1, 2, 4, 2, 0, 2, 3, 2, 3, 0, 1, 0, 2, 1, 1, 3, 0, 4,
#        4, 3, 2, 0, 2, 1, 3, 0, 1, 0, 4, 2, 2, 3, 1, 3, 4, 1, 2, 4, 0, 2,
#        0, 0, 1, 4, 4, 3, 2, 0, 3, 4, 2, 4, 3, 3, 1, 2, 0, 1, 3, 1, 0, 2,
#        0, 3, 0, 4, 0, 1, 3, 3, 3, 0, 4, 1, 1, 3, 0, 2, 2, 1, 1, 2, 2, 1,
#        3, 3, 3, 1, 3, 0, 4, 0, 4, 0])

# %%
y.shape
# Out:
# (120,)

# %%
plt.scatter(X[:, 0], X[:, 1])  # plot for both features
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 2:**

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
# Predicting values
Y_pred = kmeans.predict(X)
#Y_pred = kmeans.labels_  # another option!

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y_pred)
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 3:**

# %%
kmeans = KMeans(n_clusters=2)  # change from 5 to 2 clusters
kmeans.fit(X)
# Predicting values
Y_pred = kmeans.predict(X)
#Y_pred = kmeans.labels_  # another option!

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y_pred)
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 4:**

# %%
kmeans.inertia_
# Out:
# 1392.726100922669

# %% [markdown]
# ## K-means ++

# %% [markdown]
# **Example 1:**

# %%
kmeans = KMeans(init='k-means++', n_clusters=5)
kmeans.fit(X)
# Predicting values
Y_pred = kmeans.predict(X)
#Y_pred = kmeans.labels_  # another option!

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y_pred)
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 2:**

# %%
kmeans.inertia_
# Out:
# 149.10987744023487

# %% [markdown]
# ## Elbow Method

# %% [markdown]
# **Example 1:**

# %%
from sklearn.datasets import make_moons
import seaborn as sns
import pandas as pd
x, y = make_moons(1000, noise=.05, random_state=0)
X_moon = pd.DataFrame(x, columns = ['f1','f2'])

max_clusters = np.linspace(1, 20, num=20)
inertia_k = np.zeros((20, 2), dtype=float)

for k in range(20):
    kmeans = KMeans(init='k-means++', n_clusters=k+1)
    kmeans.fit(X)
    inertia_k[k, 0], inertia_k[k, 1] = k+1, kmeans.inertia_

# %% [markdown]
# **Example 2:**

# %%
plt.figure(figsize=(20, 5))

plt.plot(max_clusters, inertia_k[:, 1], '-o')
plt.xlabel("K number")
plt.ylabel("Inertia")
plt.xticks(max_clusters, max_clusters)
plt.show()

# %% [markdown]
# As for Elbow Method, I take 'K' equal to 4, as an optimal value

# %%
from sklearn.datasets import make_moons
import seaborn as sns
import pandas as pd
 
'''x, y = make_moons(1000, noise=.05, random_state=0)
X_moon = pd.DataFrame(x, columns = ['f1','f2'])'''
#TODO: Kmeans
kmeans = KMeans(init='k-means++', n_clusters=4)  # choosen value from Elbow Method?
kmeans.fit(X_moon)
# Predicting values
y_km = kmeans.predict(X_moon)
centers = kmeans.cluster_centers_
 
#Plot
X_moon['k_means'] = y_km
sns.lmplot(data=X_moon, x='f1', y='f2', fit_reg=False, hue = 'k_means', palette = ['#eb6c6a', '#6aeb6c', '#00b2ee', '#ffb90f']).set(title='Algorytm k-srednich')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.5)
plt.show()

# %% [markdown]
# There is typical example, where the 'KMeans' algorithm does not cluster the data correctly

# %% [markdown]
# ## Clustering II - hierarchical methods
# **Dendograms**

# %%
X, y_true = make_blobs(n_samples=300, centers=5, cluster_std=0.8, random_state=0)

# %%
X
# Out:
# array([[10.15348268, -1.29275205],
#        [-0.34538052,  8.23226077],
#        [ 0.42061579,  4.1840797 ],
#        [ 8.19491487, -2.94042833],
#        [-1.13191059,  2.82499911],
#        [-1.57620513,  2.83203804],
#        [ 1.13032158,  1.52262214],
#        [ 1.88779063,  3.31592667],
#        [ 3.25085516, -0.75832436],
#        [-1.02390241,  7.04096113],
#        [ 9.09762239, -3.19839892],
#        [ 8.24950387, -2.79951459],
#        [ 2.17153334,  4.13966072],
#        [-0.88232329,  7.0637704 ],
#        [-1.28481894,  8.01186614],
#        [ 0.72702805,  4.3487196 ],
#        [ 0.26604148,  2.71915015],
#        [ 2.02384127, -0.03681114],
#        [ 9.44403925, -3.29802855],
#        [-2.93161648,  3.27862983],
#        [ 2.00067424,  2.26833784],
#        [-0.92915335,  1.9667263 ],
#        [ 1.14289006,  5.08509856],
#        [10.21835809, -2.83669263],
#        [-0.96813829,  2.92089897],
#        [ 1.66781904,  3.71005531],
#        [-1.77561295,  2.99580239],
# ...

# %% [markdown]
# **Example 1:**

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Examaple 2:**

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Predicting values
Y_pred = kmeans.predict(X)
#Y_pred = kmeans.labels_  # another option!

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y_pred)
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %% [markdown]
# **Example 3:**

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
Z = linkage(X)
dn = dendrogram(Z)

# %% [markdown]
# **Exmaple 4:**

# %%
X_new = X[:10]

Z = linkage(X_new)
dn = dendrogram(Z)

# %% [markdown]
# **Agglomerative clustering**

# %%
import os
path = os.getcwd() + '/shopping_data.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# **Example 5:**

# %%
#data_new = data.iloc[:, 3:5]
data_new = data[["Annual Income (k$)","Spending Score (1-100)"]]  # another option!

# %%
data_new
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %% [markdown]
# **Example 6, 7:**

# %%
Z = linkage(data_new, 'single')
dn = dendrogram(Z)

# %%
Z = linkage(data_new, 'average')
dn = dendrogram(Z)

# %%
Z = linkage(data_new, 'complete')
dn = dendrogram(Z)

# %%
Z = linkage(data_new, 'ward')
dn = dendrogram(Z)

# %% [markdown]
# **Example 8, 9:**

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
fig, ax = plt.subplots(4, 4)  # plotting linear regression on subplots 
fig.set_size_inches(20, 15)
ax = ax.T.ravel()  # to iterate by columns!

clusters = np.linspace(2, 5, 4)
methods = ['single', 'average', 'complete', 'ward']
data_new = np.array(data_new, dtype=float)
num = 0

for i in range(len(methods)):
    for j in range(len(clusters)):
        agglomerative = AgglomerativeClustering(n_clusters=int(clusters[j]), linkage=methods[i])
        Y_pred = agglomerative.fit_predict(data_new)
        ax[num].scatter(data_new[:, 0], data_new[:, 1], c=Y_pred)
        ax[num].set_title('{} assigns, {} clusters'.format(methods[i], int(clusters[j])))
        num += 1
    
plt.show()

# %% [markdown]
# ## Selecting the number of clusters with silhouette analysis on KMeans clustering**

# %% [markdown]
# **Example 1:**

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

X, y = make_blobs(n_samples=500, n_features=2, centers=4, cluster_std=1, center_box=(-10.0, 10.0), shuffle=True, random_state=1)

# %% [markdown]
# **Example 2:**

# %%
range_n_clusters = np.linspace(2, 6, 5)

# %% [markdown]
# **Example 3:**

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
X, y = make_blobs(
    n_samples=500,
    n_features=2,
    centers=4,
    cluster_std=1,
    center_box=(-10.0, 10.0),
    shuffle=True,
    random_state=1,
)  # For reproducibility

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(
        X[:, 0], X[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
    )

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(
        centers[:, 0],
        centers[:, 1],
        marker="o",
        c="white",
        alpha=1,
        s=200,
        edgecolor="k",
    )

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(
        "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.7049787496083262
# For n_clusters = 3 The average silhouette_score is : 0.5882004012129721
# For n_clusters = 4 The average silhouette_score is : 0.6505186632729437
# For n_clusters = 5 The average silhouette_score is : 0.5745566973301872
# For n_clusters = 6 The average silhouette_score is : 0.4387644975296138

# %% [markdown]
# **DBSCAN algorithm**

# %%
from sklearn import  datasets
 
 
# ============
# Generate datasets.
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None
 
# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)
 
# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# %%
fig, ax = plt.subplots(6, 3)  # plotting linear regression on subplots 
fig.set_size_inches(20, 15)
#ax = ax.T.ravel()  # to iterate by columns!
ax[0, 0].set_title('KMeans')
ax[0, 1].set_title('Agglomerative')
ax[0, 2].set_title('DBSCAN')

data = [noisy_circles, noisy_moons, blobs, no_structure, aniso, varied]
clusters = [2, 2, 3, 3, 3, 3]

for i in range(len(data)):
    kmeans = KMeans(n_clusters=clusters[i])
    agglomerative = AgglomerativeClustering(n_clusters=clusters[i])
    dbscan = DBSCAN()
    kmeans_pred = kmeans.fit_predict(data[i][0], data[i][1])
    agglomerative_pred = agglomerative.fit_predict(data[i][0], data[i][1])
    dbscan_pred = dbscan.fit_predict(data[i][0], data[i][1])
    ax[i, 0].scatter(data[i][0][:, 0], data[i][0][:, 1], c=kmeans_pred)
    ax[i, 1].scatter(data[i][0][:, 0], data[i][0][:, 1], c=agglomerative_pred)
    ax[i, 2].scatter(data[i][0][:, 0], data[i][0][:, 1], c=dbscan_pred)
    
plt.show()

# %% [markdown]
# In this situation, none of the algorithms did well, especially the DBSCAN
